# %%
pip install docx2txt
# Out:
# Requirement already satisfied: docx2txt in c:\users\muthu r\appdata\local\programs\python\python310\lib\site-packages (0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx2txt
import pandas as pd
import sklearn

# %%
resume =docx2txt.process('Muthu.docx') #load the file

# %%
print(resume)
# Out:
# R.MUTHU
#
#
#
# PANDI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 79 SOUTH STREET
#
#
#
#
#
#
#
# AMMAPURAM
#
#
#
#
#
#
#
#
#
#
#
#
#
# Email: asrmuthu57 @gmail.com
#
#
#
#
#
#
#
#
#
#
#
# ALAZAPURI PO
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
# Contact no: 7904688429
#
#
#
#
#
#  THENI . 625523.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# R.MUTHU
#
#
#
# PANDI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 79 SOUTH STREET
#
#
#
#
#
#
#
# AMMAPURAM
#
#
#
#
#
#
#
#
#
#
#
#
#
# Email: asrmuthu57 @gmail.com
#
#
#
#
#
#
#
#
#
#
#
# ALAZAPURI PO
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
# Contact no: 7904688429
#
#
#
#
#
#  THENI . 625523.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	CAREER OBJECTIVE:
#
# I want to be part of the success in an environment of growth and excellence.  And I want learn new things day by day.
#
# ACADEMIC PROFILE:
#
#     Course
#
#  Name of School / College
#
# Board/University
#
# Percentage /
#
# CGPA
#
# 	Year  of
#
# passing
#
#  B-TECH(IT)
#
#
#
# 	ANNA  UNIVERSITY
#
# (BIT CAMPUS), TRICHY.
#
#
#
# Anna University
#
# 61
#
# 2017
#
#
#
#
#
#    HSC
#
# DEVANGER  HIGHER SECONDARY
#
# SCHOOL,  CHINNALA  PATTI
#
#  State Board
#
# 85
#
# 2013
#
#
#
#
#
#  SSLC
#
# DEVANGER  HIGHER
#
# 	SECONDARY  SCHOOL,
#
# CHINNALA PATTI.
#
# State Board
#
# 96
#
# 2011
#
#
#
# SKILLS:
#
# LANGUAGES  AND SKILS:  XML, XSLT, CSL, XSL-FO, XHTML,XPP.
#
# AGILE METHODOLOGY
#
# I AM INTERESTED TO LEARN NEW TECHNOLOGIES.
#
#
#
# TOTAL WORKING EXPERIENCES: 4 Years
#
# ORGANIZATIONS
#
#
#
# 1 .RR DONNELY
#
#
#
# Designation     : Document Specialist
#
# Project name  : Xyvision
#
# Project detail : XML to PDF conversion using XSLT and XPP.
#
# Skills               : XML,XSLT,HTML5,XPP.
#
# Industry         :  Publishing, Finance.
#
# Duration        :  Dec 2017 –  June 2019
#
#
#
# 2. SPS
#
#
#
# Designation    : Senior Programmer.
#
# Project name : COAST
#
# We created a tool to support clients and sps production team. The tool is mainly working on xml to client xml, xml to pdf, Docx to pdf, Html to Pdf.
#
# Skills              : XML,XSLT,XSL FO,CSL,XHTML.
#
# Industry        :  Publishing.
#
# Clients           : Springer, Wiley.
#
# Duration       : June 2019  –  Present.
#
#
#
#
#
# PERSONAL DETAILS:
#
#              Name                                 : R MUTHU PANDI
#
#              Father’s name  	       : S.RAJ
#
#             DOB                                   :19-11-1995
#
#              Sex                                    : Male
#
#              Mother tongue  	      : Tamil
#
#              Nationality                        :  Indian
#
#              Positives            	       : Self-Motivator, never-die-attitude
#
#              Languages known             : Tamil, English.
#
# 	             Hobbies                             : Bike ride, Reading Newspaper, Cricket
#
# DECLARATION:
#
#          I hereby declare that the information furnished above is true to the best of my knowledge.
#
# 						Date:                                                                                                      Yours obediently,
#
# 						Place:                                                                                                    (MUTHU PANDI)

# %%
with open("textfile.txt","r") as f:
    job_description = f.read()
    print(job_description)
# Out:
# looking for a senior developer with 3+ years in XSLT.
#
# Developer who can work on the XML based technologies
#
# like XSLT, XPath, XML Schema.
# LANGUAGES  AND SKILS:  XML, XSLT, CSL, XSL-FO, XHTML,XPP.XML,XSLT,HTML5,XPP.AGILE METHODOLOGY
#
# Developer should be able to do the data analysis and create scripts in XSLT.
#
# Developer should have fair understanding of DTD and XML schema.
# We created a tool to support clients and sps production team. The tool is mainly working on xml to client xml, xml to pdf, Docx to pdf, Html to Pdf.XML to PDF conversion using XSLT and XPP.Springer, Wiley.
#
# Past experience of creating automation through XSLT would be added advantage.
#
# Experience in e-publishing domain would be preferable-
#
# Anna University ,State Board

# %%
content =[job_description, resume]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
matrix = cv.fit_transform(content) #train the algoritham

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_mat = cosine_similarity(matrix) #test the algoritham

# %%
print(similarity_mat)
# Out:
# [[1.         0.60534801]
#  [0.60534801 1.        ]]

# %%
print("resume match percentage for this job: " + str(similarity_mat[0][1]*100)+'')#1st row 2column and 2nd row 1st column
# Out:
# resume match percentage for this job: 60.53480062718186
